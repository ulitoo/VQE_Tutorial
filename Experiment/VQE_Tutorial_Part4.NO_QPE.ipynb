# %% [markdown]
# # Tutorial on Variational Quantum Eigensolver (Part IV)
# # Quantum Phase Estimation to estimate Energy
#
# ---
# This code was mostly based on Qiskit Variational Quantum Eigensolver Playground, you can find in [Github](https://github.com/JavaFXpert/vqe-playground). Please run all the cells in order.
#
# We try to get the energy estimation in this Notebook with the [QPE: Quantum Phase estimation Algorithm.](https://en.wikipedia.org/wiki/Quantum_phase_estimation_algorithm)
#
# Part of the QPE is the [I-QFT: Inverse Quantum Fourier Transform](https://en.wikipedia.org/wiki/Quantum_Fourier_transform)
#
# We detail the steps in the Notebook but we end up with the conclusion that it is **not the best way to proceed**.
#
# The prerequisite of QPE is that the Ansatz or wavefunction used as input is a very good aproximationt to the actual Eigenvector we are looking for. Hence it will not really serve our purposes and we will see that there is not even convergence in the majority of the cases.

# %% [markdown]
# ## Import libraries
#
# We import all necessary functions from IBM qiskit and numpy python **libraries**, that we will later use on this Notebook.

# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute, IBMQ
from qiskit.circuit.library import QFT
from qiskit.visualization import plot_bloch_multivector, plot_histogram

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %% [markdown]
# ## Definition of the Circuit
# We already went through the details of classes `CircuitGridNode` and `CircuitGridModel` in PART I

# %%
class CircuitGridNode():
    def __init__(self, node_type, radians=0.0, ctrl_a=-1):
        self.node_type = node_type
        self.radians = radians
        self.ctrl_a = ctrl_a
        self.wire_num = -1
        self.column_num = -1

# %% [markdown]
# For the Class: **`CircuitGridModel`** , we are going to add the extra Quantum Circuit necessary to do the Hamiltonian expectation value and the corresponding measurement. In this 'Brute Force' PartII tutorial we will just meassure the 5 qubits.
#
# Hence we are not adding extra quibits or Gates in the initialization segment now.

# %%
class CircuitGridModel():

    def __init__(self):
        # Define the Quantum Circuit to generate the Ansatz + Other Measurement Circuit
        self.max_wires = NUM_QUBITS
        self.max_columns = 21        # Columns for the circuit. 21 Columns for the Entanglement/Tuning Circuit
                                     # NUM_QUBITS_PHASE extra phase qubits, 3 extra columns for Hadamard and Control Z.
        self.nodes = np.empty((self.max_wires + NUM_QUBITS_PHASE, self.max_columns + 3),
                                dtype = CircuitGridNode)
                
        for column_num in range(self.max_columns):
            for wire_num in range(self.max_wires):
                if column_num % 5 == 0:
                    self.nodes[wire_num][column_num] = CircuitGridNode(Ygate, np.pi)              # Ry(pi)
                    self.nodes[wire_num][column_num].wire_num = wire_num
                    self.nodes[wire_num][column_num].column_num = column_num
                else: 
                    if wire_num != 0 and wire_num == column_num % 5:
                        self.nodes[wire_num][column_num] = CircuitGridNode(Xgate, 0, wire_num-1)  # CNOT 
                        self.nodes[wire_num][column_num].wire_num = wire_num
                        self.nodes[wire_num][column_num].column_num = column_num
                        
        for wire_num in range(NUM_QUBITS_PHASE):
                    self.nodes[wire_num+NUM_QUBITS][21] = CircuitGridNode(Hgate)                  # Hadamard 
                    self.nodes[wire_num+NUM_QUBITS][21].wire_num = wire_num+NUM_QUBITS  
                    self.nodes[wire_num+NUM_QUBITS][21].column_num = 21      
                    
        # Control H_i                    
        self.nodes[5][22] = CircuitGridNode(Zgate, 5, 4)  # CZ4    we initialize with Z3 Z4 as example 
        self.nodes[5][23] = CircuitGridNode(Zgate, 5, 3)  # CZ3    
        self.nodes[5][22].wire_num = 5  ;  self.nodes[5][22].column_num = 22
        self.nodes[5][23].wire_num = 5  ;  self.nodes[5][23].column_num = 23

    def Control_Hi(self, index):
        # Make the Hadamard Test Circuit different for each and every H sum Term
        # H1 = (3/2)Z0Z1   ;   H2 = (1/2)Z0Z2   ;   H3 = (3/2)Z0Z3
        # H4 = (3/2)Z2Z3   ;   H5 = (2/2)Z1Z4   ;   H6 = (2/2)Z3Z4 
        if index == 0:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 0)  # CZ0
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 1)  # CZ1   
        elif index == 1:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 0)  # CZ0
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 2)  # CZ2   
        elif index == 2:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 0)  # CZ0
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 3)  # CZ3   
        elif index == 3:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 2)  # CZ2
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 3)  # CZ3   
        elif index == 4:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 1)  # CZ1
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 4)  # CZ4   
        elif index == 5:
            self.nodes[5][22] = CircuitGridNode(Zgate, 5, 3)  # CZ3
            self.nodes[5][23] = CircuitGridNode(Zgate, 5, 4)  # CZ4   

    def get_rotation_gate_nodes(self):
        rot_gate_nodes = []
        for column_num in range(self.max_columns):
            for wire_num in range(self.max_wires):
                node = self.nodes[wire_num][column_num]
                if node and node.node_type == Ygate:
                    rot_gate_nodes.append(node)
        return rot_gate_nodes
    
    def compute_circuit(self):
        qr = QuantumRegister(NUM_QUBITS, 'q')
        qp = QuantumRegister(NUM_QUBITS_PHASE, 'phase')
        cr = ClassicalRegister(NUM_QUBITS_PHASE, 'c')
        qc = QuantumCircuit(qr, qp, cr)
        # Build the Circuit with actual gates based on the Circuit Grid Model
        for column_num in range(self.max_columns+3):
            qc.barrier(qr) ; qc.barrier (qp) ; qc.barrier (qp)
            for wire_num in range(self.max_wires+NUM_QUBITS_PHASE):
                node = self.nodes[wire_num][column_num]
                if node:
                    if node.node_type == Xgate:    qc.cx(node.ctrl_a, wire_num)       # Controlled X gate
                    elif node.node_type == Ygate:  qc.ry(node.radians, wire_num)      # Rotation around Y axis
                    elif node.node_type == Zgate:  qc.cz(node.ctrl_a, wire_num)       # Controlled Z gate
                    elif node.node_type == Hgate:  qc.h(wire_num)                     # Hadamard Gate
                        
        # Append an Inverse QFT circuit of the correct size:
        qc.append(QFT(num_qubits=NUM_QUBITS_PHASE, approximation_degree=0, do_swaps=True, inverse=True, insert_barriers=True, name='InverseQFT'),qp)
        #qc.append(QFT(num_qubits=NUM_QUBITS_PHASE, approximation_degree=0, do_swaps=True, inverse=False, insert_barriers=True, name='QFT'),qp)
        qc.barrier(qr)
        # Add Measurement at the end
        qc.measure(qp, cr) 
        
        return qc

    def compute_circuit_ansatz(self):
        # Function aimed to measure the final Ansatz
        qr = QuantumRegister(NUM_QUBITS, 'q')
        cr = ClassicalRegister(NUM_QUBITS, 'c')
        qc = QuantumCircuit(qr, cr)
    
        # Build the Circuit with actual gates based on the Circuit Grid Model
        for column_num in range(self.max_columns):
            for wire_num in range(self.max_wires):
                node = self.nodes[wire_num][column_num]
                if node:
                    if node.node_type == Xgate:    qc.cx(node.ctrl_a, wire_num)       # Controlled X gate
                    elif node.node_type == Ygate:  qc.ry(node.radians, wire_num)      # Rotation around Y axis
        
        # Add Measurement at the end
        qc.measure(qr, cr)       
        return qc

# %% [markdown]
# ## Global Functions:
#
# `ExperimentAndMeasure` Sets up the Qiskit Simulator, Executes the simulation `n_experiments` times and return the results as an histogram (dictionary of results in the format: {'000': n1, '001': n2 ....}). In this case we will be measuring only the ancilla qubit.
#
# Also we define an array with all de weights of the $H_i$ and a temporary array `Energies_Hi` that will help us store the partial expectation values as we go calculating each one of the 6 terms of the sum.

# %%
# H1 = (3/2)Z0Z1   ;   H2 = (1/2)Z0Z2   ;   H3 = (3/2)Z0Z3
# H4 = (3/2)Z2Z3   ;   H5 = (2/2)Z1Z4   ;   H6 = (2/2)Z3Z4 
Sum_Term_Weights = [3/2,1/2,3/2,3/2,1,1]          # This array will hold the weight of every H_i term.
Energies_Hi = [0,0,0,0,0,0]                       # This will hold the expectation Values of the terms H_i.

def ExperimentAndMeasure(circuit):
    backend_sim = Aer.get_backend('qasm_simulator')
    job_sim = execute(circuit, backend_sim, shots=n_experiments)
    result_sim = job_sim.result()
    prob_distro = result_sim.get_counts(circuit)
    return prob_distro

def Phasedict_to_number(prob_distro):
    Prob_i=[]
    for name in basis_states_phase:
        prob_distro.setdefault(name, 0)
        Prob_i.append(float(prob_distro.get(name))/n_experiments)
    return np.argmax(Prob_i)

def Ansatzdict_to_number(prob_distro):
    Prob_i=[]
    for name in basis_states:
        prob_distro.setdefault(name, 0)
        Prob_i.append(float(prob_distro.get(name))/n_experiments)
    return np.argmax(Prob_i)

# %% [markdown]
# ## Global Function to Recalculate Circuit and Recalculate Expectation Value
# This function will first make use of the array `optimized_rotations` that hold the latest optimal angles for all the Ry Gates. It will assign those angles to the nodes contained in `rotation_gate_nodes` which are the nodes in the circuit subject to rotation (Ry).
#
# After that, it will compute the new circuit in the Class `circuit_grid_model` and will obtain the ansatz state and Measure it correspondingly with `ExperimentAndMeasure`.
#
# That function will in turn give the probability distribution that will be input in the `calc_expectation_value` function that at last will return the estimated Energy, most probable base state and the actual probability distribution as well.

# %%
def calc_new_energy(circuit_grid_model, rotation_gate_nodes):
    
    for idx in range(len(rotation_gate_nodes)):
        rotation_gate_nodes[idx].radians = optimized_rotations[idx]
        
    for i in range(6):
        circuit_grid_model.Control_Hi(i)
        circuit = circuit_grid_model.compute_circuit()
        prob_distro = ExperimentAndMeasure(circuit)
        angle = Phasedict_to_number(prob_distro) * 2 * np.pi / (2**NUM_QUBITS_PHASE)     # Estimated Phase
        Energies_Hi[i] = Sum_Term_Weights[i] * np.cos(angle)                             # Estimated Eigenval
        #print(circuit)
        #print(prob_distro)
        #print("phase:",Phasedict_to_number(prob_distro))
        
    #print (Energies_Hi)
    estimated_Energy = sum(Energies_Hi)
    return estimated_Energy

# %% [markdown]
# ## Global Function to Optimize Rotations
# This function will contain the **classical optimization algorithm** to finetune the angles and make sure that the Energy of the resulting state will be minimal.
#
# As input it will gate the, the Class with the Circuit, the Class with the Expectation grid and the array of nodes with Ry Gates. As output it will proyect the latest optimized energy the variable `energy` and the latest *optimal* basis state (basis state with highest probability)
#
# `cur_rotation_num` will be the node containing the Ry Gate currently being updated and optimized. Will be a counter 25 times. For each gate, the algorithm will start rotating a fixed angle on one direction, if the Energy stays or decreasis it will continue rotating, if it increases, then it will change direction of rotation unless it already changed direction before. In that case or if the angle is out of the $ [0,2\pi] $ range, it will move to the next gate.

# %%
def optimize_rotations(circuit_grid_model, rotation_gate_nodes):
    global energy, move_radians, cur_rotation_num, rot_direction, Fin_optimizacion

    if cur_rotation_num < len(optimized_rotations):   # Are we on the last Ry Gate?
        cur_ang_rad = optimized_rotations[cur_rotation_num]
        proposed_cur_ang_rad = cur_ang_rad
        proposed_cur_ang_rad += move_radians * rot_direction
        
        if (0.0 <= proposed_cur_ang_rad <= np.pi * 2 + 0.01) and (num_times_rot_dir_change[cur_rotation_num]<2):
            optimized_rotations[cur_rotation_num] = proposed_cur_ang_rad               
            
            # Calculate new Energy with the new Circuit, Quantum Qiskit circuit is called here.
            temp_energy = calc_new_energy(circuit_grid_model, rotation_gate_nodes)
            if temp_energy > energy: 
                # NOT OPTIMIZED. Distance is increasing so restore the angle and change direction of rot
                optimized_rotations[cur_rotation_num] = cur_ang_rad
                rot_direction *= -1
                num_times_rot_dir_change[cur_rotation_num] += 1
            else:
                # OPTIMIZED or equal. Distance decreasing, so keep the proposed angle and update Energy
                energy = temp_energy
        else:                                       
            cur_rotation_num += 1       # Out of [0,2pi] range or changed direction twice. Move to next Gate.
    else:
        Fin_optimizacion = True         # We reached the last Ry, optimization process is over    
    
    return energy

# %% [markdown]
# ## Definitions and Initializations
# In this segment of code we will initialize global variables that will be used in the Main and optimization algorithm. One of the important variables is the Rotation step. Note the Adjacency Matrix does not show up as it is embedded in the Hamiltonian we have manually calculated.

# %%
NUM_QUBITS = 5                                                 # Qubits to model the problem
NUM_QUBITS_PHASE = 5                                          # Qubits to code the phase in QPE
Xgate = 1 ; Ygate = 2 ; Zgate = 3 ; Hgate = 4                  # Gate Definitions     
basis_states_phase = []                                        # List of Basis states in Text format
for idx in range(2**NUM_QUBITS_PHASE):
    state = format(idx, '0' + str(NUM_QUBITS_PHASE) + 'b')
    basis_states_phase.append(state)
basis_states = []  
for idx in range(2**NUM_QUBITS):
    state = format(idx, '0' + str(NUM_QUBITS) + 'b')
    basis_states.append(state)
    
n_experiments = 1024
cur_rotation_num = 0
proposed_cur_ang_rad = 0
cur_ang_rad = 0
rot_direction = 1
move_radians = np.pi / 7                 # Rotation Step

# %% [markdown]
# ## Initialization of the Circuit and Visual Output
# Here we will initialize the circuit for first time and will calculate the Ansatz State of the all the Ry gates with $\pi$ radians. Also it will create the expectation grid for the first time.
#
# When the expectation grid is initialized, it will convert the Adjacency matrix to the Ising Hamiltonian and will print its output in gate format (I and Z gates)
#
# On this piece of code we also print the Quantum Optimization Circuit using the Qiskit drawing capabilities as well as the Latex output extensions included in the Qiskit programming language to show the Adjacency Matrix in a readable manner.

# %%
circuit_grid_model = CircuitGridModel()
circuit = circuit_grid_model.compute_circuit()

print("\nComplete Quantum Circuit:")
display(circuit.draw(output='latex', scale=0.7, plot_barriers=False))

# In case we want to see inside the InverseQFT:
# decomposed_circuit = circuit.decompose() 
# display(decomposed_circuit.draw(output='latex',scale=0.7,plot_barriers=False))
# Out:
# Complete Quantum Circuit:
# <PIL.Image.Image image mode=RGB size=3686x649 at 0x2CC957EA160>

# %% [markdown]
# ## Main Loop and Print Results
# First extract all nodes with gates suitable for rotation ans intialize first rotation of those with $\pi$. At the beginning, all Ry Gates will be indeed Pauli Y Gates.
#
# After that we will run the first Optimization iteration befor going to the actual main loop.
#
# In the main loop showing as a `while` we will **print** the Iteration number, the rotating gate, the position in the 5x21 matrix, the energy of this iteration, and the optimal basis state so far.
#
# Then we will try to **optimize** calling `optimize_rotations` function. During the optimization we will also print the simulated Ansatz State that results after the optimization quantum circuit. The output will be a **sum of the basis states and its probability**.
#
# Once the optimization comes to an end and we get out of the loop we will print the final Energy and Optimal Base State as a result

# %%
circuit_grid_model = CircuitGridModel()
circuit = circuit_grid_model.compute_circuit()

# INITIALIZATION OF FIRST CIRCUIT AND FIRST ENERGY
# Random angles at the beginning
rotation_gate_nodes = circuit_grid_model.get_rotation_gate_nodes()
optimized_rotations = np.full(len(rotation_gate_nodes), 2 * np.pi * np.random.default_rng().random())
#optimized_rotations = np.full(len(rotation_gate_nodes), np.pi)
iteration=0

energy = calc_new_energy(circuit_grid_model, rotation_gate_nodes)

# MAIN OPTIMIZATION LOOP    
nloops = 5
for i in range(nloops):
    Fin_optimizacion = False  
    cur_rotation_num = 0
    num_times_rot_dir_change = np.zeros(len(optimized_rotations))
    while not Fin_optimizacion:
        if cur_rotation_num != len(optimized_rotations):
            print(' Iteration #' + str(iteration+1) , ', Rotating Gate #' , str(cur_rotation_num+1) , 
            '(Wire, Column) = (', rotation_gate_nodes[cur_rotation_num].wire_num+1, ',' , 
            rotation_gate_nodes[cur_rotation_num].column_num+1, '). Energy:', "{:.6f}".format(energy))
        energy = optimize_rotations(circuit_grid_model, rotation_gate_nodes)
        iteration +=  1

# Extract the latest Ansatz (near EigenState) for the Histogram given the latest optimization circuit
circuit = circuit_grid_model.compute_circuit_ansatz()
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = execute(circuit, backend_sim, shots=1024)
result_sim = job_sim.result()
prob_distro = result_sim.get_counts(circuit)

# PRINT FINAL RESULT        
print("\n-------------------------------------------------------- \n")
print('Final Energy: ', "{:.6f}".format(np.real(energy)))
print("\n-------------------------------------------------------- \n")
print('Final Ansatz:',prob_distro)
print("\n-------------------------------------------------------- \n")
print('Most probable state:',format(Ansatzdict_to_number(prob_distro),'05b'))
print("\n-------------------------------------------------------- \n")
# Out:
#  Iteration #1 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 4.000000
#  Iteration #2 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 4.000000
#  Iteration #3 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 4.000000
#  Iteration #4 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 4.000000
#  Iteration #5 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 4.000000
#  Iteration #6 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 4.000000
#  Iteration #7 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 4.000000
#  Iteration #8 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 4.000000
#  Iteration #9 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 3.971178
#  Iteration #10 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 3.971178
#  Iteration #11 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 3.971178
#  Iteration #12 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #13 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #14 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #15 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #16 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #17 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #18 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #19 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #20 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #21 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #22 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #23 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #24 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #25 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #26 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #27 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #28 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #29 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #30 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #31 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #32 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #33 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #34 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #35 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #36 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #37 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #38 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #39 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #40 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #41 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #42 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #43 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #44 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #45 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #46 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #47 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #48 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #49 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #50 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #51 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #52 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #53 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #54 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #55 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #56 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #57 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #58 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #59 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #60 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #61 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #62 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #63 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #64 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #65 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #66 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #67 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #68 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #69 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #70 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #71 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #72 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #73 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #74 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #75 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #76 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #77 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #78 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #79 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #80 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #81 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #82 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #83 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #84 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #85 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #87 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #88 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #89 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #90 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #91 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #92 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #93 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #94 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #95 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #96 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #97 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #98 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #99 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #100 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #101 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #102 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #103 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #104 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #105 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #106 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #107 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #108 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #109 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #110 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #111 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #112 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #113 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #114 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #115 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #116 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #117 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #118 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #119 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #120 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #121 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #122 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #123 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #124 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #125 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #126 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #127 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #128 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #129 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #130 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #131 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #132 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #133 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #134 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #135 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #136 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #137 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #138 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #139 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #140 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #141 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #142 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #143 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #144 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #145 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #146 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #147 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #148 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #149 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #150 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #151 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #152 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #153 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #154 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #155 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #156 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #157 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #158 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #159 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #160 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #161 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #162 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #163 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #164 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #165 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #166 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #167 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #169 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #170 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #171 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #172 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #173 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #174 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #175 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #176 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #177 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #178 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #179 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #180 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #181 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #182 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #183 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #184 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #185 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #186 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #187 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #188 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #189 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #190 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: 1.000000
#  Iteration #191 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #192 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #193 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: 1.000000
#  Iteration #194 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #195 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #196 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: 1.000000
#  Iteration #197 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #198 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #199 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: 1.000000
#  Iteration #200 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #201 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #202 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: 1.000000
#  Iteration #203 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #204 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #205 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: 1.000000
#  Iteration #206 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #207 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #208 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #209 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: 1.000000
#  Iteration #210 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #211 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #212 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: 1.000000
#  Iteration #213 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #214 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #215 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: 1.000000
#  Iteration #216 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #217 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #218 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: 1.000000
#  Iteration #219 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #220 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #221 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: 1.000000
#  Iteration #222 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #223 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #224 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: 1.000000
#  Iteration #225 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #226 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #227 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: 1.000000
#  Iteration #228 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #229 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #230 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: 1.000000
#  Iteration #231 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #232 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #233 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: 1.000000
#  Iteration #234 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #235 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #236 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #237 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: 1.000000
#  Iteration #238 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #239 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #240 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: 1.000000
#  Iteration #241 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #242 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #243 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: 1.000000
#  Iteration #244 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #245 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #246 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #247 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: 1.000000
#  Iteration #249 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #250 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #251 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #252 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #253 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: 1.000000
#  Iteration #254 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #255 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #256 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: 1.000000
#  Iteration #257 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #258 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #259 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: 1.000000
#  Iteration #260 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #261 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #262 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #263 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: 1.000000
#  Iteration #264 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #265 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #266 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #267 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: 1.000000
#  Iteration #268 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #269 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: 1.000000
#  Iteration #270 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: -2.000000
#  Iteration #271 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: -2.000000
#  Iteration #272 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #273 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #274 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #275 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #276 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #277 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #278 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #279 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #280 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #281 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #282 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #283 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #284 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #285 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #286 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #287 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #288 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #289 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #290 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #291 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #292 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #293 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #294 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #295 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #296 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #297 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #298 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #299 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #300 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #301 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #302 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #303 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #304 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #305 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #306 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #307 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #308 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #309 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #310 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #311 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #312 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #313 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #314 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #315 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #316 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #317 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #318 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #319 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #320 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #321 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #322 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #323 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #324 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #325 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #326 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #327 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #328 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #330 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: -2.000000
#  Iteration #331 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: -2.000000
#  Iteration #332 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: -2.000000
#  Iteration #333 , Rotating Gate # 1 (Wire, Column) = ( 1 , 1 ). Energy: -2.000000
#  Iteration #334 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: -2.000000
#  Iteration #335 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: -2.000000
#  Iteration #336 , Rotating Gate # 2 (Wire, Column) = ( 2 , 1 ). Energy: -2.000000
#  Iteration #337 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: -2.000000
#  Iteration #338 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: -2.000000
#  Iteration #339 , Rotating Gate # 3 (Wire, Column) = ( 3 , 1 ). Energy: -2.000000
#  Iteration #340 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: -2.000000
#  Iteration #341 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: -2.000000
#  Iteration #342 , Rotating Gate # 4 (Wire, Column) = ( 4 , 1 ). Energy: -2.000000
#  Iteration #343 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: -2.000000
#  Iteration #344 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: -2.000000
#  Iteration #345 , Rotating Gate # 5 (Wire, Column) = ( 5 , 1 ). Energy: -2.000000
#  Iteration #346 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: -2.000000
#  Iteration #347 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: -2.000000
#  Iteration #348 , Rotating Gate # 6 (Wire, Column) = ( 1 , 6 ). Energy: -2.000000
#  Iteration #349 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #350 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #351 , Rotating Gate # 7 (Wire, Column) = ( 2 , 6 ). Energy: -2.000000
#  Iteration #352 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #353 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #354 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #355 , Rotating Gate # 8 (Wire, Column) = ( 3 , 6 ). Energy: -2.000000
#  Iteration #356 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #357 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #358 , Rotating Gate # 9 (Wire, Column) = ( 4 , 6 ). Energy: -2.000000
#  Iteration #359 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #360 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #361 , Rotating Gate # 10 (Wire, Column) = ( 5 , 6 ). Energy: -2.000000
#  Iteration #362 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #363 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #364 , Rotating Gate # 11 (Wire, Column) = ( 1 , 11 ). Energy: -2.000000
#  Iteration #365 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #366 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #367 , Rotating Gate # 12 (Wire, Column) = ( 2 , 11 ). Energy: -2.000000
#  Iteration #368 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #369 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #370 , Rotating Gate # 13 (Wire, Column) = ( 3 , 11 ). Energy: -2.000000
#  Iteration #371 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #372 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #373 , Rotating Gate # 14 (Wire, Column) = ( 4 , 11 ). Energy: -2.000000
#  Iteration #374 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #375 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #376 , Rotating Gate # 15 (Wire, Column) = ( 5 , 11 ). Energy: -2.000000
#  Iteration #377 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #378 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #379 , Rotating Gate # 16 (Wire, Column) = ( 1 , 16 ). Energy: -2.000000
#  Iteration #380 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #381 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #382 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #383 , Rotating Gate # 17 (Wire, Column) = ( 2 , 16 ). Energy: -2.000000
#  Iteration #384 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #385 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #386 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #387 , Rotating Gate # 18 (Wire, Column) = ( 3 , 16 ). Energy: -2.000000
#  Iteration #388 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #389 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #390 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #391 , Rotating Gate # 19 (Wire, Column) = ( 4 , 16 ). Energy: -2.000000
#  Iteration #392 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #393 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #394 , Rotating Gate # 20 (Wire, Column) = ( 5 , 16 ). Energy: -2.000000
#  Iteration #395 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #396 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #397 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #398 , Rotating Gate # 21 (Wire, Column) = ( 1 , 21 ). Energy: -2.000000
#  Iteration #399 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #400 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #401 , Rotating Gate # 22 (Wire, Column) = ( 2 , 21 ). Energy: -2.000000
#  Iteration #402 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #403 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #404 , Rotating Gate # 23 (Wire, Column) = ( 3 , 21 ). Energy: -2.000000
#  Iteration #405 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #406 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #407 , Rotating Gate # 24 (Wire, Column) = ( 4 , 21 ). Energy: -2.000000
#  Iteration #408 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #409 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #410 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#  Iteration #411 , Rotating Gate # 25 (Wire, Column) = ( 5 , 21 ). Energy: -2.000000
#
# --------------------------------------------------------
#
# Final Energy:  -2.000000
#
# --------------------------------------------------------
#
# Final Ansatz: {'00001': 6, '10000': 10, '10001': 117, '10010': 4, '10100': 1, '10101': 88, '10110': 1, '10111': 25, '11000': 5, '11001': 1, '11010': 11, '11011': 7, '11100': 13, '11101': 68, '11110': 7, '00011': 2, '00101': 407, '00110': 12, '00111': 112, '01000': 1, '01001': 69, '01010': 2, '01011': 55}
#
# --------------------------------------------------------
#
# Most probable state: 00101
#
# --------------------------------------------------------

# %% [markdown]
# ## Histogram of Ansatz Measurements

# %%
print('Histogram: ')
plot_histogram(prob_distro, title="Ansatz Measurement")
# Out:
# Histogram:
